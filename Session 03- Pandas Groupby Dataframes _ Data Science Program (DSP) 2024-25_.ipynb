# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/LearnDataSci/articles/refs/heads/master/Python%20Pandas%20Tutorial%20A%20Complete%20Introduction%20for%20Beginners/IMDB-Movie-Data.csv')
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
group = df.groupby(['Director' , 'Actors'])['Metascore'].mean().head().sort_values(ascending = False)
group.agg(['min' , 'count' , 'sum'])
# Out:
# min       42.0
# count      5.0
# sum      339.0
# Name: Metascore, dtype: float64

# %%
group
# Out:
# min       42.0
# count      5.0
# sum      339.0
# Name: Metascore, dtype: float64

# %%
print(df.groupby('Year')['Votes'])

# %%
df.groupby('Year')['Votes']

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/M0hamedIbrahim1/Sales-Data-Analysis/refs/heads/main/Dataset/December_2019.csv')
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       295665          Macbook Pro Laptop                1       1700
# 1       295666          LG Washing Machine                1      600.0
# 2       295667        USB-C Charging Cable                1      11.95
# 3       295668            27in FHD Monitor                1     149.99
# 4       295669        USB-C Charging Cable                1      11.95
# ...        ...                         ...              ...        ...
# 25112   319666    Lightning Charging Cable                1      14.95
# 25113   319667       AA Batteries (4-pack)                2       3.84
# 25114   319668             Vareebadd Phone                1        400
# 25115   319669            Wired Headphones                1      11.99
# 25116   319670  Bose SoundSport Headphones                1      99.99
#
#            Order Date                        Purchase Address
# ...

# %%
df.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %%
duplicates = df.groupby('Product')['Purchase Address'].unique()
duplicates

# %%
duplicates = df.groupby('Product')['Purchase Address'].value_counts()
duplicates
# Out:
# Product       Purchase Address
# 20in Monitor  103 Dogwood St, New York City, NY 10001     1
#               103 Sunset St, Dallas, TX 75001             1
#               105 Chestnut St, San Francisco, CA 94016    1
#               106 7th St, Los Angeles, CA 90001           1
#               106 Cherry St, Seattle, WA 98101            1
#                                                          ..
# iPhone        994 12th St, New York City, NY 10001        1
#               995 Cedar St, Austin, TX 73301              1
#               996 Sunset St, Boston, MA 02215             1
#               997 12th St, San Francisco, CA 94016        1
#               999 Cherry St, San Francisco, CA 94016      1
# Name: count, Length: 24873, dtype: int64

# %%
sales_data = df.groupby('Product')['Price Each'].count()
sales_data
# Out:
# Product
# 20in Monitor                   568
# 27in 4K Gaming Monitor         860
# 27in FHD Monitor               962
# 34in Ultrawide Monitor         846
# AA Batteries (4-pack)         2717
# AAA Batteries (4-pack)        2831
# Apple Airpods Headphones      2059
# Bose SoundSport Headphones    1808
# Flatscreen TV                  662
# Google Phone                   715
# LG Dryer                        86
# LG Washing Machine              80
# Lightning Charging Cable      2894
# Macbook Pro Laptop             644
# Product                         48
# ThinkPad Laptop                541
# USB-C Charging Cable          2981
# Vareebadd Phone                285
# Wired Headphones              2542
# iPhone                         908
# Name: Price Each, dtype: int64

# %%
item = df.groupby('Product')
item

# %%
item.nunique()
# Out:
#                             Order ID  Quantity Ordered  Price Each  \
# Product
# 20in Monitor                     568                 2           1
# 27in 4K Gaming Monitor           858                 2           1
# 27in FHD Monitor                 962                 2           1
# 34in Ultrawide Monitor           845                 2           1
# AA Batteries (4-pack)           2708                 7           1
# AAA Batteries (4-pack)          2823                 7           1
# Apple Airpods Headphones        2054                 3           1
# Bose SoundSport Headphones      1804                 2           1
# Flatscreen TV                    660                 2           1
# Google Phone                     715                 2           1
# LG Dryer                          86                 1           1
# LG Washing Machine                80                 1           1
# Lightning Charging Cable        2888                 4           1
# ...

# %%
item.nunique()
# Out:
#                             Order ID  Quantity Ordered  Price Each  \
# Product
# 20in Monitor                     568                 2           1
# 27in 4K Gaming Monitor           858                 2           1
# 27in FHD Monitor                 962                 2           1
# 34in Ultrawide Monitor           845                 2           1
# AA Batteries (4-pack)           2708                 7           1
# AAA Batteries (4-pack)          2823                 7           1
# Apple Airpods Headphones        2054                 3           1
# Bose SoundSport Headphones      1804                 2           1
# Flatscreen TV                    660                 2           1
# Google Phone                     715                 2           1
# LG Dryer                          86                 1           1
# LG Washing Machine                80                 1           1
# Lightning Charging Cable        2888                 4           1
# ...

# %%
sales_data = df.groupby('Product')[['Price Each' , 'Quantity Ordered']]
sales_data.describe()
# Out:
#                            Price Each                           \
#                                 count unique         top  freq
# Product
# 20in Monitor                      568      1      109.99   568
# 27in 4K Gaming Monitor            860      1      389.99   860
# 27in FHD Monitor                  962      1      149.99   962
# 34in Ultrawide Monitor            846      1      379.99   846
# AA Batteries (4-pack)            2717      1        3.84  2717
# AAA Batteries (4-pack)           2831      1        2.99  2831
# Apple Airpods Headphones         2059      1         150  2059
# Bose SoundSport Headphones       1808      1       99.99  1808
# Flatscreen TV                     662      1         300   662
# Google Phone                      715      1         600   715
# LG Dryer                           86      1       600.0    86
# LG Washing Machine                 80      1       600.0    80
# Lightning Charging Cable         2894      1       14.95  2894
# ...

# %%
def check_in_alpha(sales_data):
  return sales_data['Product'].str.startswith('2').sum()

# %%
df = pd.read_csv('https://raw.githubusercontent.com/marcusklasson/GroceryStoreDataset/refs/heads/master/dataset/classes.csv')
df
# Out:
#     Class Name (str)  Class ID (int) Coarse Class Name (str)  \
# 0   Golden-Delicious               0                   Apple
# 1       Granny-Smith               1                   Apple
# 2          Pink-Lady               2                   Apple
# 3      Red-Delicious               3                   Apple
# 4         Royal-Gala               4                   Apple
# ..               ...             ...                     ...
# 76          Red-Beet              76                Red-Beet
# 77       Beef-Tomato              77                  Tomato
# 78    Regular-Tomato              78                  Tomato
# 79       Vine-Tomato              79                  Tomato
# 80          Zucchini              80                Zucchini
#
#     Coarse Class ID (int)                            Iconic Image Path (str)  \
# 0                       0  /iconic-images-and-descriptions/Fruit/Apple/Go...
# ...

# %%
group = df.groupby('Class Name (str)')[['Coarse Class Name (str)' , 'Product Description Path (str)' , 'Iconic Image Path (str)']]
group.describe()
# Out:
#                          Coarse Class Name (str)                        \
#                                            count unique       top freq
# Class Name (str)
# Alpro-Blueberry-Soyghurt                       1      1  Soyghurt    1
# Alpro-Fresh-Soy-Milk                           1      1  Soy-Milk    1
# Alpro-Shelf-Soy-Milk                           1      1  Soy-Milk    1
# Alpro-Vanilla-Soyghurt                         1      1  Soyghurt    1
# Anjou                                          1      1      Pear    1
# ...                                          ...    ...       ...  ...
# Yellow-Bell-Pepper                             1      1    Pepper    1
# Yellow-Onion                                   1      1     Onion    1
# Yoggi-Strawberry-Yoghurt                       1      1   Yoghurt    1
# Yoggi-Vanilla-Yoghurt                          1      1   Yoghurt    1
# Zucchini                                       1      1  Zucchini    1
#
# ...

# %%
def starts_alpha(group):
  return group['Coarse Class Name (str)'].str.startswith('P').sum()

# %%
group.apply(starts_alpha)
# Out:
# Class Name (str)
# Alpro-Blueberry-Soyghurt    0
# Alpro-Fresh-Soy-Milk        0
# Alpro-Shelf-Soy-Milk        0
# Alpro-Vanilla-Soyghurt      0
# Anjou                       1
#                            ..
# Yellow-Bell-Pepper          1
# Yellow-Onion                0
# Yoggi-Strawberry-Yoghurt    0
# Yoggi-Vanilla-Yoghurt       0
# Zucchini                    0
# Length: 81, dtype: int64

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
gross = groupf['gross'].sum().sort_values(ascending = False)
gross.head(2)
# Out:
# director_name     country
# Steven Spielberg  USA        4.014062e+09
# Michael Bay       USA        2.231243e+09
# Name: gross, dtype: float64

# %%
groupf = df.groupby(['director_name' , 'country'])

# %%
sizeofgroup = groupf.size()
sizeofgroup
# Out:
# director_name       country
# A. Raven Cruz       USA        1
# Aaron Hann          USA        1
# Aaron Schneider     USA        1
# Aaron Seltzer       USA        1
# Abel Ferrara        USA        1
#                               ..
# Zoran Lisinac       USA        1
# Álex de la Iglesia  Spain      1
# Émile Gaudreault    Canada     1
# Éric Tessier        Canada     1
# Étienne Faure       France     1
# Length: 2762, dtype: int64

# %%
twoColumnsGroup = groupf.get_group(('A. Raven Cruz' , 'USA'))
twoColumnsGroup
# Out:
#       color  director_name  num_critic_for_reviews  duration  \
# 4605  Color  A. Raven Cruz                     3.0      97.0
#
#       director_facebook_likes  actor_3_facebook_likes actor_2_name  \
# 4605                      0.0                    94.0  Vanilla Ice
#
#       actor_1_facebook_likes  gross                                  genres  \
# 4605                   639.0    NaN  Action|Adventure|Comedy|Fantasy|Sci-Fi
#
#       ... num_user_for_reviews language  country  content_rating     budget  \
# 4605  ...                    9  English      USA               R  1000000.0
#
#       title_year actor_2_facebook_likes imdb_score aspect_ratio  \
# 4605      2005.0                  361.0        1.9         1.78
#
#      movie_facebook_likes
# 4605                  128
#
# [1 rows x 28 columns]

# %%
kdf = pd.read_csv('https://raw.githubusercontent.com/Gauthamyaramasa/IMDB_Movie_Analysis_Using_Excel/refs/heads/main/IMDB_Movies_Dataset_Original.csv')
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
group = df.groupby('movie_title').head()
group
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
group = df.groupby(['director_name', 'actor_1_name'])
group.head()
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5037  Color       Edward Burns                    14.0      95.0
# 5038  Color        Scott Smith                     1.0      87.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 0                         0.0                   855.0    Joel David Moore
# ...

# %%
group.size()
# Out:
# director_name       actor_1_name
# A. Raven Cruz       Scott Levy             1
# Aaron Hann          Jordi Vilasuso         1
# Aaron Schneider     Bill Murray            1
# Aaron Seltzer       Alyson Hannigan        1
# Abel Ferrara        Isabella Rossellini    1
#                                           ..
# Zoran Lisinac       Matthew Emerick        1
# Álex de la Iglesia  Jim Carter             1
# Émile Gaudreault    Paul Sorvino           1
# Éric Tessier        Patrick Huard          1
# Étienne Faure       Rumi Missabu           1
# Length: 4530, dtype: int64

# %%
df = pd.read_csv('/content/IPL_Ball_by_Ball_2008_2022.csv')
df
# Out:
#              ID  innings  overs  ballnumber       batter          bowler  \
# 0       1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1       1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2       1312200        1      0           3   JC Buttler  Mohammed Shami
# 3       1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4       1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...         ...      ...    ...         ...          ...             ...
# 225949   335982        2     14           5      P Kumar        I Sharma
# 225950   335982        2     14           6     SB Joshi        I Sharma
# 225951   335982        2     14           7      P Kumar        I Sharma
# 225952   335982        2     15           1     SB Joshi       LR Shukla
# 225953   335982        2     15           2     SB Joshi       LR Shukla
#
#         non-striker extra_type  batsman_run  extras_run  total_run  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'innings', 'overs', 'ballnumber', 'batter', 'bowler',
#        'non-striker', 'extra_type', 'batsman_run', 'extras_run', 'total_run',
#        'non_boundary', 'isWicketDelivery', 'player_out', 'kind',
#        'fielders_involved', 'BattingTeam'],
#       dtype='object')

# %%
df.rename(columns = {'batter' : 'batsman'} , inplace = True)

# %%
group
# Out:
# batter
# V Kohli           6634
# S Dhawan          6244
# DA Warner         5883
# RG Sharma         5881
# SK Raina          5536
#                   ...
# C Nanda              0
# Akash Deep           0
# S Ladda              0
# V Pratap Singh       0
# S Lamichhane         0
# Name: batsman_run, Length: 605, dtype: int64

# %%
six = df[df['batsman_run'] == 6]

# Change 'batsman' to 'batter' in both groupby and count methods
six.groupby('batsman')['batsman'].count().sort_values(ascending = False).head(2).index[0]
# Out:
# 'CH Gayle'

# %%
temp_df = df[df['overs'] > 15]
temp_df = temp_df[(temp_df['batsman_run'] == 4) | (temp_df['batsman_run'] == 6)]
temp_df = temp_df.groupby('batsman')['batsman'].count().sort_values(ascending=False)
temp_df
# Out:
# batsman
# MS Dhoni          347
# KA Pollard        237
# AB de Villiers    218
# KD Karthik        190
# RG Sharma         168
#                  ...
# Anirudh Singh       1
# Ankit Soni          1
# Anuj Rawat          1
# PJ Sangwan          1
# NL McCullum         1
# Name: batsman, Length: 411, dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'innings', 'overs', 'ballnumber', 'batsman', 'bowler',
#        'non-striker', 'extra_type', 'batsman_run', 'extras_run', 'total_run',
#        'non_boundary', 'isWicketDelivery', 'player_out', 'kind',
#        'fielders_involved', 'BattingTeam'],
#       dtype='object')

# %%
df.columns == df[]

# %%
df['batsman']
# Out:
# 0         YBK Jaiswal
# 1         YBK Jaiswal
# 2          JC Buttler
# 3         YBK Jaiswal
# 4         YBK Jaiswal
#              ...
# 225949        P Kumar
# 225950       SB Joshi
# 225951        P Kumar
# 225952       SB Joshi
# 225953       SB Joshi
# Name: batsman, Length: 225954, dtype: object

# %%
df.columns
# Out:
# Index(['ID', 'innings', 'overs', 'ballnumber', 'batsman', 'bowler',
#        'non-striker', 'extra_type', 'batsman_run', 'extras_run', 'total_run',
#        'non_boundary', 'isWicketDelivery', 'player_out', 'kind',
#        'fielders_involved', 'BattingTeam'],
#       dtype='object')

# %%
temp_df = df[df['batsman'] == 'V Kohli']
temp_df.groupby('ID')['batsman_run'].sum().sort_values(ascending = False).head(2).values[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-104-862f0b8d499c> in <cell line: 1>()
# ----> 1 temp_df = df[df['batsman'] == batsman]
#       2 temp_df.groupby('ID')['batsman_run'].sum().sort_values(ascending = False).head(2).values[0]
#
# NameError: name 'batsman' is not defined

# %%
def highest(batsman):
  temp_df = df[df['batsman'] == batsman]
  return temp_df.groupby('ID')['batsman_run'].sum().sort_values(ascending = False).head(2).values[0]

# %%
highest('DA Warner')
# Out:
# 126
