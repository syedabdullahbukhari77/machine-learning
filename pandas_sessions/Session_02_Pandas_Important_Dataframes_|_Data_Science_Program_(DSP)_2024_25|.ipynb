# %% [markdown]
# <a href="https://colab.research.google.com/github/syedabdullahbukhari77/GoogleCollabDataScienceSeason204/blob/main/Session_02_Pandas_Important_Dataframes_%7C_Data_Science_Program_(DSP)_2024_25%7C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# Replace 'blob' with 'raw' in the URL to access the raw file content
url = 'https://raw.githubusercontent.com/sawlachintan/cricket_data/main/data/bronze/bbl/innings_df.csv'
# Removed '/raw' from the URL path as it's redundant when using 'raw.githubusercontent.com'
df = pd.read_csv(url, on_bad_lines='skip', delimiter=',')
df.head(10)
# Out:
# <ipython-input-3-a31872959f0c>:4: DtypeWarning: Columns (16,17,18,19,20,21,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url, on_bad_lines='skip', delimiter=',')
#         batter    bowler  non_striker  runs_batter  runs_extras  runs_total  \
# 0  BB McCullum     B Lee    ML Hayden            0            0           0
# 1  BB McCullum     B Lee    ML Hayden            0            0           0
# 2  BB McCullum     B Lee    ML Hayden            4            0           4
# 3  BB McCullum     B Lee    ML Hayden            0            0           0
# 4  BB McCullum     B Lee    ML Hayden            0            0           0
# 5  BB McCullum     B Lee    ML Hayden            0            0           0
# 6    ML Hayden  MA Starc  BB McCullum            0            0           0
# 7    ML Hayden  MA Starc  BB McCullum            0            0           0
# 8    ML Hayden  MA Starc  BB McCullum            4            0           4
# ...

# %%
df.columns
# Out:
# Index(['batter', 'bowler', 'non_striker', 'runs_batter', 'runs_extras',
#        'runs_total', 'over', 'delivery_no', 'batting_team', 'inning_no',
#        'replacements_role', 'wickets_kind', 'wickets_player_out',
#        'bowling_team', 'key', 'runs_non_boundary', 'replacements_match',
#        'review_by', 'review_umpire', 'review_batter', 'review_decision',
#        'review_umpires_call', 'review_type', 'extras_type'],
#       dtype='object')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/itsmecevi/dataset/main/pakistan_intellectual_capital.csv')
df
# Out:
#       Unnamed: 0    S#            Teacher Name  \
# 0              2     3         Dr. Abdul Basit
# 1              4     5         Dr. Waheed Noor
# 2              5     6        Dr. Junaid Baber
# 3              6     7     Dr. Maheen Bakhtyar
# 4             24    25             Samina Azim
# ...          ...   ...                     ...
# 1137        1974  1975        Dr. Ahmar Rashid
# 1138        1975  1976       Dr. Fawad Hussain
# 1139        1977  1978    Dr. Rashad M Jillani
# 1140        1979  1980  Dr. Shahabuddin Ansari
# 1141        1980  1981         Dr. Sajid Anwar
#
#                University Currently Teaching  \
# 0                  University of Balochistan
# 1                  University of Balochistan
# 2                  University of Balochistan
# 3                  University of Balochistan
# 4     Sardar Bahadur Khan Women's University
# ...                                      ...
# 1137             Ghulam Ishaq Khan Institute
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  S#         Teacher Name  \
# 0           2   3      Dr. Abdul Basit
# 1           4   5      Dr. Waheed Noor
# 2           5   6     Dr. Junaid Baber
# 3           6   7  Dr. Maheen Bakhtyar
# 4          24  25          Samina Azim
#
#             University Currently Teaching             Department  \
# 0               University of Balochistan  Computer Science & IT
# 1               University of Balochistan  Computer Science & IT
# 2               University of Balochistan  Computer Science & IT
# 3               University of Balochistan  Computer Science & IT
# 4  Sardar Bahadur Khan Women's University       Computer Science
#
#   Province University Located          Designation Terminal Degree  \
# 0                 Balochistan  Assistant Professor             PhD
# 1                 Balochistan  Assistant Professor             PhD
# 2                 Balochistan  Assistant Professor             PhD
# ...

# %%
# General info about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1142 entries, 0 to 1141
# Data columns (total 13 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Unnamed: 0                                 1142 non-null   int64
#  1   S#                                         1142 non-null   int64
#  2   Teacher Name                               1142 non-null   object
#  3   University Currently Teaching              1142 non-null   object
#  4   Department                                 1142 non-null   object
#  5   Province University Located                1142 non-null   object
#  6   Designation                                1123 non-null   object
#  7   Terminal Degree                            1138 non-null   object
#  8   Graduated from                             1142 non-null   object
#  9   Country                                    1142 non-null   object
# ...

# %%
# statistical summary for numeric columns
df.describe()
# Out:
#         Unnamed: 0           S#         Year
# count  1142.000000  1142.000000   489.000000
# mean   1054.350263  1055.350263  2010.456033
# std     520.202783   520.202783     5.577565
# min       2.000000     3.000000  1983.000000
# 25%     689.250000   690.250000  2008.000000
# 50%    1087.500000  1088.500000  2012.000000
# 75%    1476.750000  1477.750000  2014.000000
# max    1980.000000  1981.000000  2018.000000

# %%
# check for the null values
df.isnull().sum()
# Out:
# Unnamed: 0                                      0
# S#                                              0
# Teacher Name                                    0
# University Currently Teaching                   0
# Department                                      0
# Province University Located                     0
# Designation                                    19
# Terminal Degree                                 4
# Graduated from                                  0
# Country                                         0
# Year                                          653
# Area of Specialization/Research Interests     519
# Other Information                            1018
# dtype: int64

# %%
# identifying unique and Duplicate Values

# count unique values in each column
df.nunique()

# check for the duplicated in each rows
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# Unnamed: 0                                   1142
# S#                                           1142
# Teacher Name                                 1133
# University Currently Teaching                  63
# Department                                     17
# Province University Located                     5
# Designation                                    46
# Terminal Degree                                42
# Graduated from                                350
# Country                                        38
# Year                                           32
# Area of Specialization/Research Interests     571
# Other Information                              52
# dtype: int64

# %%
df['Teacher Name'].value_counts().head()
# Out:
# Teacher Name
# Muhammad Zubair    3
# Naila Shah         2
# Muhammad Nauman    2
# Naveed Ahmad       2
# Mehdi Hassan       2
# Name: count, dtype: int64

# %%
df['Department'].value_counts()
# Out:
# Department
# Computer Science                               744
# Computer Engineering                            81
# Information Technology                          62
# Computing                                       43
# Computer Science & IT                           41
# Computing & Information Sciences                38
# Institute of Mathematics & Computer Science     25
# FACULTY OF COMPUTING & ENGINEERING              22
# Computer Science and Software Engineering       21
# Computer and Information Sciences               19
# CS & IT                                         14
# School of Information and Technology            11
# ENGINEERING, SCIENCE & TECHNOLOGY                7
# Computer Science and Engineering                 6
# Computer Science and IT                          4
# Software Engineering                             2
# Computer Sciences                                2
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'S#', 'Teacher Name', 'University Currently Teaching',
#        'Department', 'Province University Located', 'Designation',
#        'Terminal Degree', 'Graduated from', 'Country', 'Year',
#        'Area of Specialization/Research Interests', 'Other Information'],
#       dtype='object')

# %%
df.sort_values('Teacher Name' , ascending = False )
# Out:
#       Unnamed: 0    S#               Teacher Name  \
# 912         1537  1538            Syed Nabeel Ali
# 482          971   972          Sobia Tariq Javed
# 878         1499  1500                 Ms. Kainat
# 873         1494  1495          Ms. Humaira Meraj
# 880         1504  1505         Hironao Takahashi
# ...          ...   ...                        ...
# 840         1446  1447           ABEER JAVED SYED
# 649         1232  1233        ABDUL SATTAR SOOMRO
# 148          365   366               ABDUL KALEEM
# 1035        1728  1729   Naveed Ahmad Khan Jhamat
# 122          314   315              Dr. Ali Daud
#
#                           University Currently Teaching  \
# 912   PAF-Karachi Institute of Economics and Technology
# 482                                        FAST(Lahore)
# 878                         Jinnah University for Women
# 873                         Jinnah University for Women
# 880                                DHA Suffa University
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/shishir349/Analyzing-the-IMDB-Movie-Dataset/refs/heads/master/movie_metadata.csv')
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
movies = pd.read_csv('https://raw.githubusercontent.com/LearnDataSci/articles/refs/heads/master/Python%20Pandas%20Tutorial%20A%20Complete%20Introduction%20for%20Beginners/IMDB-Movie-Data.csv')
movies
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
movies.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
movies.reset_index()
# Out:
#      index  Rank                    Title                     Genre  \
# 0        0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1        1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2        2     3                    Split           Horror,Thriller
# 3        3     4                     Sing   Animation,Comedy,Family
# 4        4     5            Suicide Squad  Action,Adventure,Fantasy
# ..     ...   ...                      ...                       ...
# 995    995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996    996   997          Hostel: Part II                    Horror
# 997    997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998    998   999             Search Party          Adventure,Comedy
# 999    999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# ...

# %%
movies.rename(columns = {'Title' : 'title' , 'Year' : 'year_of_release'})
# Out:
#      Rank                    title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
movies['Year'].notnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 995    True
# 996    True
# 997    True
# 998    True
# 999    True
# Name: Year, Length: 1000, dtype: bool

# %%
movies.isnull()
# Out:
#       Rank  Title  Genre  Description  Director  Actors   Year  \
# 0    False  False  False        False     False   False  False
# 1    False  False  False        False     False   False  False
# 2    False  False  False        False     False   False  False
# 3    False  False  False        False     False   False  False
# 4    False  False  False        False     False   False  False
# ..     ...    ...    ...          ...       ...     ...    ...
# 995  False  False  False        False     False   False  False
# 996  False  False  False        False     False   False  False
# 997  False  False  False        False     False   False  False
# 998  False  False  False        False     False   False  False
# 999  False  False  False        False     False   False  False
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 0                False   False  False               False      False
# 1                False   False  False               False      False
# ...

# %%
movies.notnull()
# Out:
#      Rank  Title  Genre  Description  Director  Actors  Year  \
# 0    True   True   True         True      True    True  True
# 1    True   True   True         True      True    True  True
# 2    True   True   True         True      True    True  True
# 3    True   True   True         True      True    True  True
# 4    True   True   True         True      True    True  True
# ..    ...    ...    ...          ...       ...     ...   ...
# 995  True   True   True         True      True    True  True
# 996  True   True   True         True      True    True  True
# 997  True   True   True         True      True    True  True
# 998  True   True   True         True      True    True  True
# 999  True   True   True         True      True    True  True
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 0                 True    True   True                True       True
# 1                 True    True   True                True       True
# ...

# %%
movies['Title'].dropna(how='all')
# Out:
# 0      Guardians of the Galaxy
# 1                   Prometheus
# 2                        Split
# 3                         Sing
# 4                Suicide Squad
#                 ...
# 995       Secret in Their Eyes
# 996            Hostel: Part II
# 997     Step Up 2: The Streets
# 998               Search Party
# 999                 Nine Lives
# Name: Title, Length: 1000, dtype: object

# %%
movies.dropna(subset = ['Title'])
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
movies.groupby('Year').sum()
# Out:
#         Rank                                              Title  \
# Year
# 2006   25894  The PrestigePirates of the Caribbean: Dead Man...
# 2007   30559  5- 25- 77Pirates of the Caribbean: At World's ...
# 2008   32533  The Dark KnightMamma Mia!TwilightTropic Thunde...
# 2009   29928  Inglourious BasterdsAvatarStar TrekWatchmenKyn...
# 2010   35239  InceptionShutter IslandDiary of a Wimpy KidSco...
# 2011   37143  Pirates of the Caribbean: On Stranger TidesThe...
# 2012   34104  PrometheusThe AvengersThe Dark Knight RisesThe...
# 2013   50617  The Wolf of Wall StreetPrisoners12 Years a Sla...
# 2014   50272  Guardians of the GalaxyInterstellarJohn WickKi...
# 2015   62407  Bahubali: The BeginningStar Wars: Episode VII ...
# 2016  111804  SplitSingSuicide SquadThe Great WallLa La Land...
#
#                                                   Genre  \
# Year
# 2006  Drama,Mystery,Sci-FiAction,Adventure,FantasyCr...
# 2007  Comedy,DramaAction,Adventure,FantasyCrime,Dram...
# ...
