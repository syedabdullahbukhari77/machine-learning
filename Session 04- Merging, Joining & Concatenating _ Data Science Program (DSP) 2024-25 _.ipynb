# %%
import pandas as pd
import numpy as np

# %%
courses = df = (pd.read_csv('/content/courses.csv'))
deliveries = df = (pd.read_csv('/content/deliveries.csv'))
matches = df = (pd.read_csv('/content/matches.csv'))
month_1 = df = (pd.read_csv('/content/reg-month1.csv'))
month_2 = df = (pd.read_csv('/content/reg-month2.csv'))
students = df = (pd.read_csv('/content/students.csv'))

# %%
month_1.shape
# Out:
# (25, 2)

# %%
month_1
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3

# %%
pd.concat([month_1 , month_2]).shape
# Out:
# (53, 2)

# %%
new_list = pd.concat([month_1 , month_2] , ignore_index = True)
new_list
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 25           3          5
# 26          16          7
# 27          12         10
# 28          12          1
# 29          14          9
# 30           7          7
# 31           7          2
# 32          16          3
# 33          17         10
# ...

# %%
pd.concat([month_1 , month_2] , keys = ['Nov' , 'Dec'])
# Out:
#         student_id  course_id
# Nov 0           23          1
#     1           15          5
#     2           18          6
#     3           23          4
#     4           16          9
#     5           18          1
#     6            1          1
#     7            7          8
#     8           22          3
#     9           15          1
#     10          19          4
#     11           1          6
#     12           7         10
#     13          11          7
#     14          13          3
#     15          24          4
#     16          21          1
#     17          16          5
#     18          23          3
#     19          17          7
#     20          23          6
#     21          25          1
#     22          19          2
#     23          25         10
#     24           3          3
# Dec 0            3          5
#     1           16          7
#     2           12         10
#     3           12          1
#     4           14          9
# ...

# %%
month_1.columns
month_2.columns
# Out:
# Index(['student_id', 'course_id'], dtype='object')

# %%
new_df = pd.merge(month_1 , month_2 , how='inner', )
new_df
# Out:
# Empty DataFrame
# Columns: [student_id, course_id]
# Index: []

# %%
new_df = pd.merge(month_1 , month_2 , how = 'outer')
new_df
# Out:
#     student_id  course_id
# 0            1          1
# 1            1          6
# 2            1          9
# 3            1         10
# 4            2          5
# 5            3          3
# 6            3          5
# 7            7          2
# 8            7          6
# 9            7          7
# 10           7          8
# 11           7         10
# 12          11          7
# 13          11          8
# 14          11         10
# 15          12          1
# 16          12          5
# 17          12          7
# 18          12         10
# 19          13          3
# 20          14          1
# 21          14          4
# 22          14          6
# 23          14          9
# 24          15          1
# 25          15          5
# 26          16          3
# 27          16          5
# 28          16          7
# 29          16          9
# 30          17          7
# 31          17         10
# 32          18          1
# 33          18          6
# ...

# %%
new_df = month_1.merge(month_2 , on = 'student_id' , how = 'left')
new_df
# Out:
#     student_id  course_id_x  course_id_y
# 0           23            1          9.0
# 1           23            1          5.0
# 2           15            5          NaN
# 3           18            6          8.0
# 4           23            4          9.0
# 5           23            4          5.0
# 6           16            9          7.0
# 7           16            9          3.0
# 8           18            1          8.0
# 9            1            1         10.0
# 10           1            1          9.0
# 11           7            8          7.0
# 12           7            8          2.0
# 13           7            8          6.0
# 14          22            3          5.0
# 15          22            3          6.0
# 16          15            1          NaN
# 17          19            4          NaN
# 18           1            6         10.0
# 19           1            6          9.0
# 20           7           10          7.0
# 21           7           10          2.0
# ...

# %%
new_df = pd.merge(month_1 , month_2 , how = 'right')

# %%
new_df
# Out:
#     student_id  course_id
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# 9           11          8
# 10          14          6
# 11          12          5
# 12          12          7
# 13          18          8
# 14           1         10
# 15           1          9
# 16           2          5
# 17           7          6
# 18          22          5
# 19          22          6
# 20          23          9
# 21          23          5
# 22          14          4
# 23          14          1
# 24          11         10
# 25          42          9
# 26          50          8
# 27          38          1
